# %% [markdown]
# # Chapter 1: Python GraphBLAS
#
# Using the python-graphblas library for sparse linear algebra on graphs.

# %%
import graphblas as gb
from graphblas import Matrix, Vector, binary, semiring
import networkx as nx
import matplotlib.pyplot as plt
from graph_utils import draw_graph, draw_vector

# %% [markdown]
# ## Creating Sparse Matrices

# %%
# Create adjacency matrix from edge list (COO format)
rows = [0, 0, 1, 2, 3]
cols = [1, 2, 2, 3, 1]
vals = [1, 1, 1, 1, 1]

A = Matrix.from_coo(rows, cols, vals, nrows=4, ncols=4, dtype=int)
print(A)
# Out:
# "M_0"      nvals  nrows  ncols  dtype         format
# gb.Matrix      5      4      4  INT64  bitmapr (iso)

# %%
# Visualize the graph
G = nx.DiGraph()
G.add_edges_from(zip(rows, cols))
draw_graph(G)
# Out:
# {0: array([-0.25361167,  0.78710236]),
#  1: array([-0.36369475, -0.08825725]),
#  2: array([0.49947487, 0.30115489]),
#  3: array([ 0.11783155, -1.        ])}

# %% [markdown]
# ## Creating Sparse Vectors

# %%
# Create a vector marking node 0 as the starting point
v = Vector.from_coo([0], [1], size=4, dtype=int)
draw_vector(v, title="Starting vector (source at node 0)")
# Out:
# <Axes: title={'center': 'Starting vector (source at node 0)'}>

# %% [markdown]
# ## Simple BFS with Matrix-Vector Multiply

# %%
# One hop: v × A using vxm
frontier = v.vxm(A, semiring.any_pair).new()
draw_vector(frontier, title="After 1 hop")
# Out:
# <Axes: title={'center': 'After 1 hop'}>

# %%
# Two hops
frontier2 = frontier.vxm(A, semiring.any_pair).new()
draw_vector(frontier2, title="After 2 hops")
# Out:
# <Axes: title={'center': 'After 2 hops'}>

# %%
# BFS loop - expand until no new nodes
frontier = Vector.from_coo([0], [1], size=4, dtype=int)
visited = frontier.dup()

level = 0
while frontier.nvals > 0:
    print(f"Level {level}: nodes {list(frontier.to_coo()[0])}")
    frontier = frontier.vxm(A, semiring.any_pair).new()
    # Remove already visited (use .S for structural mask)
    frontier(mask=~visited.S, replace=True) << frontier
    visited(binary.any) << frontier
    level += 1

print(f"\nAll visited nodes: {list(visited.to_coo()[0])}")
# Out:
# Level 0: nodes [np.uint64(0)]
# Level 1: nodes [np.uint64(1), np.uint64(2)]
# Level 2: nodes [np.uint64(3)]
#
# All visited nodes: [np.uint64(0), np.uint64(1), np.uint64(2), np.uint64(3)]
