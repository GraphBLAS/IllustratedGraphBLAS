# %% [markdown]
# # Illustrated GraphBLAS - Interactive Notebooks
#
# These notebooks accompany the Illustrated GraphBLAS video series, providing hands-on code examples for each chapter.
#
# ## Setup
#
# ```bash
# pip install python-graphblas networkx matplotlib jupyter
# ```
#
# ## Notebooks
#
# | # | Notebook | Description |
# |---|----------|-------------|
# | 0 | [Introduction](00_introduction.ipynb) | Sparse vs dense matrices, adjacency matrix basics |
# | 1 | [Python GraphBLAS](01_python_graphblas.ipynb) | Install, create sparse matrices, simple BFS |
# | 2 | [Semirings](02_semirings.ipynb) | PLUS_TIMES, MIN_PLUS, ANY_PAIR on same graph |
# | 3 | [Masking and BFS](03_masking_bfs.ipynb) | Complete BFS with complement masks |
# | 4 | [Matrix-Matrix Multiply](04_matrix_multiply.ipynb) | A², A³ for multi-hop paths |
# | 5 | [Incidence Matrices](05_incidence_matrices.ipynb) | S×D=A, multigraphs, hypergraphs |
# | 6 | [Element-wise Operations](06_elementwise_ops.ipynb) | Graph union, intersection, filtering |
# | 7 | [Shortest Path](07_shortest_path.ipynb) | SSSP and APSP with MIN_PLUS |
# | 8 | [Triangles & Centrality](08_triangles_centrality.ipynb) | Triangle counting via A²⊙A |
# | 9 | [Sparse Neural Networks](09_sparse_neural_nets.ipynb) | Sparse weights, forward propagation |
