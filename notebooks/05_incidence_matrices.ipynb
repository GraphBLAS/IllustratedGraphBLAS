# %% [markdown]
# # Chapter 5: Incidence Matrices
#
# Incidence matrices S (source) and D (destination) factor the adjacency matrix: S × D^T = A.

# %%
import graphblas as gb
from graphblas import Matrix, semiring
import networkx as nx
import matplotlib.pyplot as plt
from graph_utils import draw_graph, draw_matrix, draw_matrices_side_by_side, draw_multigraph, draw_hypergraph

# %% [markdown]
# ## Graph as Edge List

# %%
# Edges: (source, destination)
edges = [(0,1), (0,2), (1,2), (2,3)]
n_nodes = 4
n_edges = len(edges)

print("Edges:")
for i, (s, d) in enumerate(edges):
    print(f"  e{i}: {s} -> {d}")
# Out:
# Edges:
#   e0: 0 -> 1
#   e1: 0 -> 2
#   e2: 1 -> 2
#   e3: 2 -> 3

# %%
G = nx.DiGraph(edges)
pos = {0: (0,1), 1: (1,1), 2: (0.5,0), 3: (1.5,0)}
draw_graph(G, pos=pos)
# Out:
# {0: (0, 1), 1: (1, 1), 2: (0.5, 0), 3: (1.5, 0)}

# %% [markdown]
# ## Incidence Matrices

# %%
# S[node, edge] = 1 if node is source of edge
# D[node, edge] = 1 if node is destination of edge

S_rows, D_rows = [], []
for edge_idx, (src, dst) in enumerate(edges):
    S_rows.append((src, edge_idx))
    D_rows.append((dst, edge_idx))

S = Matrix.from_coo(
    [r[0] for r in S_rows], [r[1] for r in S_rows], 
    [1]*n_edges, nrows=n_nodes, ncols=n_edges, dtype=int
)
D = Matrix.from_coo(
    [r[0] for r in D_rows], [r[1] for r in D_rows],
    [1]*n_edges, nrows=n_nodes, ncols=n_edges, dtype=int
)

draw_matrices_side_by_side(
    [S, D],
    ["Source S (nodes × edges)", "Destination D (nodes × edges)"]
)
# Out:
# (<Figure size 860x430 with 2 Axes>,
#  array([<Axes: title={'center': 'Source S (nodes × edges)'}>,
#         <Axes: title={'center': 'Destination D (nodes × edges)'}>],
#        dtype=object))

# %% [markdown]
# ## S × D^T = A

# %%
# Multiply S × D^T to get adjacency matrix
A = S.mxm(D.T, semiring.plus_times).new()
draw_matrix(A, title="Adjacency matrix A = S × Dᵀ")
# Out:
# <Axes: title={'center': 'Adjacency matrix A = S × Dᵀ'}>

# %% [markdown]
# ## Multigraphs
#
# Incidence matrices naturally handle parallel edges (multiple edges between same nodes).

# %%
# Multigraph: two edges from 0 to 1
multi_edges = [(0,1), (0,1), (1,2)]
n_multi_edges = len(multi_edges)

S_multi = Matrix.from_coo(
    [e[0] for e in multi_edges], list(range(n_multi_edges)),
    [1]*n_multi_edges, nrows=3, ncols=n_multi_edges, dtype=int
)
D_multi = Matrix.from_coo(
    [e[1] for e in multi_edges], list(range(n_multi_edges)),
    [1]*n_multi_edges, nrows=3, ncols=n_multi_edges, dtype=int
)

A_multi = S_multi.mxm(D_multi.T, semiring.plus_times).new()
draw_matrix(A_multi, title="Multigraph adjacency (edge counts)")
print("A[0,1] = 2: two parallel edges from 0 to 1")
# Out:
# A[0,1] = 2: two parallel edges from 0 to 1

# %%
# Visualize the multigraph - curved edges show parallel connections
pos_multi = {0: (0, 1), 1: (1, 1), 2: (1, 0)}
draw_multigraph(multi_edges, pos=pos_multi, title="Multigraph: two edges from 0 to 1")
# Out:
# {0: (0, 1), 1: (1, 1), 2: (1, 0)}

# %% [markdown]
# ## Hypergraphs
#
# A hypergraph generalizes graphs by allowing hyperedges to connect any number of source nodes to any number of destination nodes. Like regular edges, we represent them with two incidence matrices:
# - S[node, hyperedge] = 1 if the node is a source of that hyperedge
# - D[node, hyperedge] = 1 if the node is a destination of that hyperedge

# %%
# Hypergraph example: 6 nodes, 3 hyperedges
# Each hyperedge connects a set of sources to a set of destinations
#
# Hyperedge 0: sources {0, 1} -> destinations {2, 3}
# Hyperedge 1: sources {1, 2} -> destinations {4, 5}
# Hyperedge 2: sources {0} -> destinations {3, 4, 5}

hyperedge_sources = [{0, 1}, {1, 2}, {0}]
hyperedge_dests = [{2, 3}, {4, 5}, {3, 4, 5}]
n_nodes = 6
n_hyperedges = len(hyperedge_sources)

print("Hyperedges (sources -> destinations):")
for i, (src, dst) in enumerate(zip(hyperedge_sources, hyperedge_dests)):
    print(f"  e{i}: {sorted(src)} -> {sorted(dst)}")
# Out:
# Hyperedges (sources -> destinations):
#   e0: [0, 1] -> [2, 3]
#   e1: [1, 2] -> [4, 5]
#   e2: [0] -> [3, 4, 5]

# %%
# Build source incidence matrix S[node, hyperedge]
S_rows, S_cols = [], []
for he_idx, sources in enumerate(hyperedge_sources):
    for node in sources:
        S_rows.append(node)
        S_cols.append(he_idx)

S_hyper = Matrix.from_coo(
    S_rows, S_cols,
    [1] * len(S_rows), nrows=n_nodes, ncols=n_hyperedges, dtype=int
)

# Build destination incidence matrix D[node, hyperedge]
D_rows, D_cols = [], []
for he_idx, dests in enumerate(hyperedge_dests):
    for node in dests:
        D_rows.append(node)
        D_cols.append(he_idx)

D_hyper = Matrix.from_coo(
    D_rows, D_cols,
    [1] * len(D_rows), nrows=n_nodes, ncols=n_hyperedges, dtype=int
)

draw_matrices_side_by_side(
    [S_hyper, D_hyper],
    ["Source S (nodes × hyperedges)", "Destination D (nodes × hyperedges)"]
)
# Out:
# (<Figure size 720x570 with 2 Axes>,
#  array([<Axes: title={'center': 'Source S (nodes × hyperedges)'}>,
#         <Axes: title={'center': 'Destination D (nodes × hyperedges)'}>],
#        dtype=object))

# %%
# Visualize the hypergraph - colored regions show hyperedges
# Source nodes shown with squares, destination nodes with circles
pos_hyper = {0: (0, 1), 1: (1, 1), 2: (2, 1), 3: (0.5, 0), 4: (1.5, 0), 5: (2.5, 0)}
draw_hypergraph(hyperedge_sources, hyperedge_dests, pos=pos_hyper,
                title="Hypergraph: sources (top) connect to destinations (bottom)")
# Out:
# {0: (0, 1), 1: (1, 1), 2: (2, 1), 3: (0.5, 0), 4: (1.5, 0), 5: (2.5, 0)}

# %%
# S × D^T shows connections from source nodes to destination nodes
A_hyper = S_hyper.mxm(D_hyper.T, semiring.plus_times).new()
draw_matrix(A_hyper, title="A = S × Dᵀ: source-to-destination connections")
print("A[i,j] = number of hyperedges where i is a source and j is a destination")
# Out:
# A[i,j] = number of hyperedges where i is a source and j is a destination
