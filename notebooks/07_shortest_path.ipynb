# %% [markdown]
# # Chapter 7: Shortest Path
#
# SSSP and APSP using the MIN_PLUS semiring.

# %%
import graphblas as gb
from graphblas import Matrix, Vector, semiring, binary
import networkx as nx
import matplotlib.pyplot as plt
import math
from graph_utils import draw_weighted_graph, draw_vector

# %% [markdown]
# ## Weighted Graph

# %%
# Use standard 6-node weighted graph from Chapter 0
# Edges: (0→1)=1, (0→3)=2, (1→2)=5, (3→4)=2, (3→5)=9, (4→2)=5, (5→4)=2
edges = [(0,1,1), (0,3,2), (1,2,11), (3,4,4), (3,5,1), (4,2,5), (5,4,2)]
rows, cols, weights = zip(*edges)

A = Matrix.from_coo(rows, cols, weights, nrows=6, ncols=6, dtype=float)
print("Weighted adjacency matrix:")
print(A)
# Out:
# Weighted adjacency matrix:
# "M_5"      nvals  nrows  ncols  dtype   format
# gb.Matrix      7      6      6   FP64  bitmapr

# %%
G = nx.DiGraph()
for r, c, w in edges:
    G.add_edge(r, c, weight=w)

# Triangle layout from Chapter 0
sqrt3 = math.sqrt(3)
pos = {
    0: (-3, -sqrt3),      # Base left
    1: (0, -sqrt3),       # Base center
    2: (3, -sqrt3),       # Base right
    3: (-1.5, 0),         # Middle left
    4: (1.5, 0),          # Middle right
    5: (0, sqrt3)         # Top point
}
draw_weighted_graph(G, pos=pos, title="Weighted Directed Graph")
# Out:
# {0: (-3, -1.7320508075688772),
#  1: (0, -1.7320508075688772),
#  2: (3, -1.7320508075688772),
#  3: (-1.5, 0),
#  4: (1.5, 0),
#  5: (0, 1.7320508075688772)}

# %% [markdown]
# ## Single-Source Shortest Path (SSSP)

# %%
def sssp(A, source):
    """Bellman-Ford style SSSP using MIN_PLUS semiring."""
    n = A.nrows
    
    # Initialize distances: 0 for source, absent for others
    dist = Vector(float, size=n)
    dist[source] = 0.0
    
    # Iterate until convergence
    for iteration in range(n - 1):
        new_dist = dist.dup()
        # Relax edges with MIN accumulator: new_dist = min(dist, dist × A)
        new_dist(accum=binary.min) << dist.vxm(A, semiring.min_plus)
        
        if new_dist.isequal(dist):
            print(f"Converged after {iteration + 1} iterations")
            break
        dist = new_dist
    
    return dist

distances = sssp(A, source=0)
draw_vector(distances, title="Shortest distances from node 0")
# Out:
# Converged after 5 iterations
# <Axes: title={'center': 'Shortest distances from node 0'}>

# %%
# Verify with NetworkX
nx_distances = nx.single_source_dijkstra_path_length(G, 0)
print("NetworkX verification:")
for node, dist in sorted(nx_distances.items()):
    print(f"  Node {node}: {dist}")
# Out:
# NetworkX verification:
#   Node 0: 0
#   Node 1: 1
#   Node 2: 10
#   Node 3: 2
#   Node 4: 5
#   Node 5: 3

# %% [markdown]
# ## All-Pairs Shortest Path (APSP)

# %%
def apsp(A):
    """Floyd-Warshall style APSP using MIN_PLUS semiring."""
    n = A.nrows
    
    # Initialize with adjacency matrix + zero diagonal
    D = A.dup()
    D.setdiag(0)
    
    # Repeated matrix multiply until convergence
    for _ in range(int(math.log2(n)) + 1):
        # Relax with MIN accumulator: D_new = min(D, D × D)
        D(accum=binary.min) << D.mxm(D, semiring.min_plus)    
    return D

all_pairs = apsp(A)
print("All-pairs shortest distances:")
print(all_pairs)
# Out:
# All-pairs shortest distances:
# "M_1"      nvals  nrows  ncols  dtype   format
# gb.Matrix     18      6      6   FP64  bitmapr

# %%
# Visualize the all-pairs shortest distances as a complete weighted graph
rows, cols, vals = all_pairs.to_coo()

# Create a graph with all shortest path edges (excluding self-loops)
G_apsp = nx.DiGraph()
for i in range(all_pairs.nrows):
    G_apsp.add_node(i)
for r, c, w in zip(rows, cols, vals):
    if r != c:  # Skip self-loops (distance 0 to self)
        G_apsp.add_edge(int(r), int(c), weight=int(w))

# Position nodes in a circle for better visibility of all connections
pos_apsp = nx.circular_layout(G_apsp)
draw_weighted_graph(G_apsp, pos=pos_apsp, title="All-Pairs Shortest Distances")
# Out:
# {0: array([1.00000000e+00, 2.45045699e-08]),
#  1: array([0.49999998, 0.86602546]),
#  2: array([-0.50000004,  0.8660254 ]),
#  3: array([-9.99999970e-01, -6.29182054e-08]),
#  4: array([-0.49999989, -0.86602541]),
#  5: array([ 0.49999992, -0.86602541])}
